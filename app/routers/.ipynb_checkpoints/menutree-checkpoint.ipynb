# %%
from fastapi import APIRouter
import logging

router = APIRouter(
    prefix="/menutree",
    tags=["MenuTree"]
)

logger = logging.getLogger("MES_API")

@router.get("/")
def health():
    logger.info("healthcheck API called")
    return {
        "status": "Healthy",
        "version": "1.0.0",
        "details": None
    }
