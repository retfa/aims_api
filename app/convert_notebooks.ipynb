# %%
# convert_notebooks_api.py
from nbconvert import PythonExporter
import nbformat
import os
import time

NOTEBOOK_DIR = r"C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app"

def convert_notebooks_api(base_dir):
    for root, dirs, files in os.walk(base_dir):
        # 忽略 .ipynb_checkpoints 資料夾
        dirs[:] = [d for d in dirs if d != ".ipynb_checkpoints"]

        for file in files:
            if file.endswith(".ipynb") and "convert_notebooks" not in file:
                notebook_path = os.path.join(root, file)
                py_path = notebook_path.replace(".ipynb", ".py")

                # 只轉最近修改的 notebook
                if os.path.exists(py_path):
                    if os.path.getmtime(py_path) >= os.path.getmtime(notebook_path):
                        # .py 比 notebook 新 → 跳過
                        print(f"略過（未修改）: {notebook_path}")
                        continue

                print(f"正在轉換: {notebook_path}")

                # 讀 notebook
                nb_node = nbformat.read(notebook_path, as_version=4)
                exporter = PythonExporter()
                source, _ = exporter.from_notebook_node(nb_node)

                # 寫入 .py
                with open(py_path, "w", encoding="utf-8") as f:
                    f.write(source)

    print("全部轉換完成！")

if __name__ == "__main__":
    start_time = time.time()

    convert_notebooks_api(NOTEBOOK_DIR)

    end_time = time.time() - start_time
    print("總轉換時間:", end_time)
# Out:
# 正在轉換: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\main.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\__init__.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\core\app_logging.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\core\config.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\core\security.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\db\session.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\dependencies\auth.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\CostSheet.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\CostSheet_Maintenance.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\get_gz_data.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\MES.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\Staff_meal_ordering_system.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\System.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\Vehicle_entry_management.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\resources\WSP.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\aug.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\authentication.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\business_intelligence.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\business_intelligence_history.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\coatingweight_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\consumption.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\costsheet_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\department.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\dining.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_diff_data_feature_importance_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_diff_data_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_feature_importance_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_gramg_speed_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_machine_run_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_outputlist_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_out_spec_count_reel_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_out_spec_count_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_prediction_status_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\gz_data_user_favorite_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\healthcheck.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\machine.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\menu.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\menutree.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\mes_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\outputlist_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\paper_quality_standard.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\permission_cross_department.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\permission_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\program.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\redis_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\skyeye.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\staff_meal_ordering_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\station.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\system_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\user_router.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\routers\wintriss.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\authentication_login.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\coatingweight_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\costsheet_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_diff_data_feature_importance_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_diff_data_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_feature_importance_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_gramg_speed_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_machine_run_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_outputlist_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_out_spec_count_reel_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_out_spec_count_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_prediction_status_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\gz_data_user_favorite_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\menu.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\mes_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\outputlist_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\permission_cross_department_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\permission_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\skyeye.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\staff_meal_ordering_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\user_schema.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\schemas\wintriss.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\authentication_login.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\coatingweight_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\costsheet_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_diff_data_feature_importance_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_diff_data_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_feature_importance_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_gramg_speed_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_machine_run_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_outputlist_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_out_spec_count_reel_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_out_spec_count_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_prediction_status_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\gz_data_user_favorite_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\menu.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\mes_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\outputlist_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\permission_cross_department_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\permission_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\redis_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\skyeye.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\staff_meal_ordering_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\system_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\user_service.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\services\wintriss.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\utils\async_utils.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\utils\db_connections.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\utils\db_engine.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\utils\filepath.ipynb
# 略過（未修改）: C:\Users\Jason.Ouyang\Downloads\OuYang\Python\20250204_PM21_GreenZone\app\utils\server_manager.ipynb
# 全部轉換完成！
# 總轉換時間: 0.317150354385376
